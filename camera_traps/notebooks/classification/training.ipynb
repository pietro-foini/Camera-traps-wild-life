# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %%
import os
import datetime
import pathlib
import json

import pandas as pd
import numpy as np
import tensorflow as tf
import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import ConvNeXtBase
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import imagesize
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788532166.967895  380962 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1788532167.077654  380962 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
print(tf.__version__)
# Out:
# 2.21.0

# %%
# Get the GPUs available.
tf.config.list_physical_devices("GPU")
# Out:
# W0000 00:00:1788532170.998082  380962 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Load data
#
# The current dataset was assembled by combining multiple online data sources to gather camera trap images captured in both daytime and nighttime settings. Subsequently, all images were manually reviewed to filter out noisy, misleading, or poorly identifiable samples, ensuring higher dataset quality. The data was collected over several years; therefore, we cannot guarantee that the provided links remain active or publicly accessible.
#
# List of sources:
#
# - NTLNP: https://paperswithcode.com/dataset/ntlnp-wildlife-image-dataset
# - CCT20: https://lila.science/datasets/caltech-camera-traps
# - Sheffield: https://figshare.shef.ac.uk/articles/dataset/Badger_datasets_for_image_recognition/8182370/1
# - ENA24: https://lila.science/datasets/ena24detection
# - LilaMissouri: https://lila.science/datasets/missouricameratraps
# - WCS: https://lila.science/datasets/wcscameratraps
# - PennFudan: https://www.cis.upenn.edu/~jshi/ped_html/
# - yybbdog: https://www.lirmm.fr/YT-BB-Dog_Sibetan/
# - nz: https://lila.science/datasets/nz-trailcams
# - idaho: https://lila.science/datasets/idaho-camera-traps/
# - felidae: https://lila.science/datasets/felidae-conservation-fund
# - island: https://lila.science/datasets/channel-islands-camera-traps/
# - seattleish: https://lila.science/datasets/seattleish-camera-traps/
# - nkhotakota: https://lila.science/datasets/nkhotakota-camera-traps/
# - roboflow: https://roboflow.com/
# - oregon: https://lila.science/datasets/oregon-critters/
# - maasai: https://lila.science/datasets/biome-health-project-maasai-mara
# - UKCEH: https://catalogue.ceh.ac.uk/documents/bf82cec2-5f8a-407c-bf74-f8689ca35e83
# - MOF: https://github.com/umr-ds/Mammal-Bird-Camera-Trap-Recognition/blob/main/data/data_download.sh
# - BNP: https://github.com/umr-ds/Mammal-Bird-Camera-Trap-Recognition/blob/main/data/data_download.sh
#
# N.B. It should be noted that a small degree of noise or minor misclassifications may still persist in certain classes due to edge cases in image quality, lighting, or subject occlusion.

# %%
DATASET_PATH = "../../../dataset/"

# %%
data = []
for file in pathlib.Path(DATASET_PATH).glob("*/*"):
    data.append({"filename": file.resolve().as_posix(), "label": file.resolve().parent.name})

# Load data into dataframe.
df = pd.DataFrame(data)
# Get extra information about data source and time condition.
df[["dataset", "time"]] = df["filename"].str.split("/").str[-1].str.extract(r"^([^_]+)_[^_]+_([^_]+)")
df["size"] = df["filename"].apply(imagesize.get)
df["width"], df["height"] = zip(*df["size"])
# Let's filter out small images.
df = df[(df["width"] > 100) | (df["height"] > 100)]
df.drop(columns=["size", "width", "height"], inplace=True)
df.head()
# Out:
#                                             filename  label     dataset time
# 0  /home/pietr/projects/camera-traps-wild-life/da...  human  seattleish  day
# 1  /home/pietr/projects/camera-traps-wild-life/da...  human   PennFudan  day
# 2  /home/pietr/projects/camera-traps-wild-life/da...  human   PennFudan  day
# 3  /home/pietr/projects/camera-traps-wild-life/da...  human  seattleish  day
# 4  /home/pietr/projects/camera-traps-wild-life/da...  human          nz  day

# %%
len(df)
# Out:
# 74227

# %%
df.groupby("label")["filename"].nunique().sort_values(ascending=False)
# Out:
# label
# deer                 8725
# dog                  8242
# cat                  7623
# boar                 5855
# human                4832
# cow                  4752
# bear                 4619
# hare                 4446
# None_of_the_above    4435
# weasel               4365
# fox                  3321
# wolf                 3136
# squirrel             2697
# vehicle              2639
# bird                 2317
# badger               2223
# Name: filename, dtype: int64

# %%
df.groupby(["label", "time"])["filename"].nunique()
# Out:
# label              time
# None_of_the_above  day      3798
#                    night     637
# badger             day       870
#                    night    1353
# bear               day      3308
#                    night    1311
# bird               day      1853
#                    night     464
# boar               day      3460
#                    night    2395
# cat                day      2970
#                    night    4653
# cow                day      4162
#                    night     590
# deer               day      5180
#                    night    3545
# dog                day      7285
#                    night     957
# fox                day      1200
#                    night    2121
# hare               day      1722
#                    night    2724
# human              day      4671
#                    night     161
# squirrel           day      2570
#                    night     127
# vehicle            day      2592
# ...

# %%
df.groupby("dataset")["filename"].nunique().sort_values(ascending=False)
# Out:
# dataset
# NTLNP           19998
# CCT20           12766
# idaho            5214
# felidae          4310
# ENA24            4226
# UKCEH            3281
# nz               2844
# PennFudan        2818
# island           2693
# seattleish       2688
# yybbdog          2213
# nkhotakota       2138
# roboflow         1615
# oregon           1471
# casanova         1325
# UPENN             990
# Sheffield         928
# unspecified       741
# google            586
# MOF               523
# WCS               521
# maasai            148
# BNP               130
# LilaMissouri       60
# Name: filename, dtype: int64

# %%
class_names = df["label"].unique().tolist()
class_names
# Out:
# ['human',
#  'vehicle',
#  'bird',
#  'cow',
#  'fox',
#  'hare',
#  'dog',
#  'cat',
#  'None_of_the_above',
#  'weasel',
#  'bear',
#  'deer',
#  'badger',
#  'squirrel',
#  'wolf',
#  'boar']

# %% [markdown]
# ## Split data into training and validation sets

# %%
df_train, df_val = train_test_split(
    df, 
    test_size=0.2,
    shuffle=True, 
    random_state=42, 
    stratify=df[["label", "time", "dataset"]],
)

# %%
len(df_train), len(df_val)
# Out:
# (59381, 14846)

# %%
df_train.groupby("label")["filename"].nunique().sort_values(ascending=False)
# Out:
# label
# deer                 6980
# dog                  6592
# cat                  6097
# boar                 4685
# human                3867
# cow                  3803
# bear                 3695
# hare                 3556
# None_of_the_above    3548
# weasel               3492
# fox                  2657
# wolf                 2508
# squirrel             2158
# vehicle              2112
# bird                 1854
# badger               1777
# Name: filename, dtype: int64

# %%
df_val.groupby("label")["filename"].nunique().sort_values(ascending=False)
# Out:
# label
# deer                 1745
# dog                  1650
# cat                  1526
# boar                 1170
# human                 965
# cow                   949
# bear                  924
# hare                  890
# None_of_the_above     887
# weasel                873
# fox                   664
# wolf                  628
# squirrel              539
# vehicle               527
# bird                  463
# badger                446
# Name: filename, dtype: int64

# %% [markdown]
# ## Load and preprocess images
#
# For further details: https://www.tensorflow.org/tutorials/load_data/images#using_tfdata_for_finer_control.

# %%
img_size = 224
batch_size = 32

# %%
def load_and_preprocess_image(file_path, label):
    img = tf.io.read_file(file_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [img_size, img_size])
    one_hot = label == class_names
    return img, tf.argmax(one_hot)

# %%
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filename"].values, df_train["label"].values))
val_ds = tf.data.Dataset.from_tensor_slices((df_val["filename"].values, df_val["label"].values))
# Out:
# W0000 00:00:1788518209.963738  195098 gpu_device.cc:2459] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 12.0a. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# I0000 00:00:1788518210.163417  195098 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5233 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 12.0a

# %%
train_ds = train_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(20, 6))
for i, (image, label) in enumerate(train_ds.take(18)):
    ax = plt.subplot(3, 6, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.title(class_names[label])
    plt.axis("off")

# %% [markdown]
# ## Data augmentation

# %%
img_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.15),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.2),
]

def img_augmentation(images):
    for layer in img_augmentation_layers:
        images = layer(images)
    return images

# %%
for image, label in train_ds.take(3):
    plt.figure(figsize=(20, 6))
    for i in range(18):
        ax = plt.subplot(3, 6, i + 1)
        aug_img = img_augmentation(np.expand_dims(image.numpy(), axis=0))
        aug_img = np.array(aug_img)
        plt.imshow(aug_img[0].astype("uint8"))
        plt.title(class_names[label])
        plt.axis("off")

# %% [markdown]
# ## Prepare inputs

# %%
def input_preprocess_train(image, label):
    image = img_augmentation(image)
    return image, label

# Train data.
train_ds = train_ds.map(input_preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.shuffle(buffer_size=1000)
train_ds = train_ds.batch(batch_size=batch_size)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
# Validation data.
val_ds = val_ds.batch(batch_size=batch_size)

# %% [markdown]
# # Training

# %%
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

# %%
def build_model(num_classes, image_size):
    inputs = layers.Input(shape=(image_size, image_size, 3))
    model = ConvNeXtBase(include_top=False, input_tensor=inputs, weights="imagenet")
    
    model.trainable = False

    # Rebuild top.
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, kernel_regularizer=keras.regularizers.l2(0.005), activation="softmax", name="pred")(x)

    # Compile.
    model = keras.Model(inputs, outputs, name="ConvNeXt")
    optimizer = keras.optimizers.Adam(learning_rate=1e-3)
    model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    
    return model

# %%
model = build_model(len(class_names), img_size)
model.summary()
# Out:
# Model: "ConvNeXt"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_base_pres… │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_base_stem  │ (None, 56, 56,    │      6,528 │ convnext_base_pr… │
# │ (Sequential)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# ## Transfer Learning
#
# The most common incarnation of transfer learning in the context of deep learning is the following workflow:
#
# - Take layers from a previously trained model.
# - Freeze them, so as to avoid destroying any of the information they contain during future training rounds.
# - Add some new, trainable layers on top of the frozen layers. They will learn to turn the old features into predictions on a new dataset.
# - Train the new layers on your dataset.

# %%
epochs = 10

history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    epochs=epochs,
    shuffle=False,
    validation_freq=5,
)
# Out:
# Epoch 1/10
# I0000 00:00:1788472038.116139    4430 service.cc:153] XLA service 0x294913f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1788472038.116168    4430 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 5060 Laptop GPU, Compute Capability 12.0a (Driver: 13.3.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.24.0)
# I0000 00:00:1788472038.452189    4430 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1788472040.038536    4430 cuda_dnn.cc:461] Loaded cuDNN version 92400
# I0000 00:00:1788472040.243623    4430 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_37042__.642
# E0000 00:00:1788472041.515109    4430 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ...

# %% [markdown]
# ## Fine Tuning
#
# Fine-tuning, which consists of unfreezing the entire model you obtained above (or part of it), and re-training it on the new data with a very low learning rate. This can potentially achieve meaningful improvements, by incrementally adapting the pretrained features to the new data.

# %%
def unfreeze_model(model):
    for layer in model.layers:
        if (
            "stage_3" in layer.name
            or layer.name
            in [
                "layer_normalization",
                "avg_pool",
                "batch_normalization",
                "top_dropout",
                "pred",
            ]
        ):
            layer.trainable = True

    optimizer = keras.optimizers.AdamW(learning_rate=1e-5, weight_decay=0.05)
    model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

unfreeze_model(model)

# %%
model.summary()
# Out:
# Model: "ConvNeXt"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_base_pres… │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_base_stem  │ (None, 56, 56,    │      6,528 │ convnext_base_pr… │
# │ (Sequential)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
epochs = 50

early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

tensorboard_callback = TensorBoard(
    logdir, 
    histogram_freq=1
)

history = model.fit(
    train_ds, 
    validation_data=val_ds,
    epochs=epochs, 
    shuffle=False,
    validation_freq=1,
    callbacks=[early_stopping, tensorboard_callback]
)
# Out:
# Epoch 1/50
# I0000 00:00:1788475317.243104    4430 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_146264__.642
# E0000 00:00:1788475321.884970    4430 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1788475322.873257    7941 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_1_282', 4 bytes spill stores, 4 bytes spill loads
# 1855/1856 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9101 - loss: 0.3738
# I0000 00:00:1788475697.556722    4430 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_146264__.642
# I0000 00:00:1788475698.371576    8236 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_442', 4 bytes spill stores, 4 bytes spill loads
#
# ...

# %% [raw]
# model.save("model.keras")
#
# with open("class_names.json", "w") as f:
#     json.dump({i: c for i, c in enumerate(class_names)}, f)

# %%
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-9e2be70b7e61c119" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9e2be70b7e61c119");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
predictions = model.predict(val_ds)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.concatenate([labels.numpy() for images, labels in val_ds], axis=0)
# Out:
# I0000 00:00:1788518228.535097  371972 service.cc:153] XLA service 0x24c71050 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1788518228.535144  371972 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 5060 Laptop GPU, Compute Capability 12.0a (Driver: 13.3.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.24.0)
# I0000 00:00:1788518228.608266  371972 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1788518228.923200  371972 cuda_dnn.cc:461] Loaded cuDNN version 92400
# E0000 00:00:1788518230.421534  371972 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ...

# %%
cm = confusion_matrix(true_classes, predicted_classes, labels=list(range(len(class_names))))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot();

# %%
print(classification_report(true_classes, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       965
#            1       1.00      1.00      1.00       527
#            2       0.98      0.98      0.98       463
#            3       1.00      1.00      1.00       949
#            4       0.99      0.98      0.98       664
#            5       0.99      1.00      0.99       890
#            6       0.99      0.99      0.99      1650
#            7       0.99      0.99      0.99      1526
#            8       0.99      0.98      0.99       887
#            9       1.00      0.99      0.99       873
#           10       0.99      1.00      0.99       924
#           11       1.00      1.00      1.00      1745
#           12       0.99      0.99      0.99       446
#           13       0.99      1.00      0.99       539
#           14       0.98      0.99      0.99       628
#           15       0.99      0.98      0.99      1170
#
# ...
